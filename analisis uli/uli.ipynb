# %%
import os
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
#open data
dla = pd.read_excel('01DLA_DaiMon_S19.xlsx')
tnm = pd.read_excel('03TNM_DaiMon_S2.xlsx')
pas = pd.read_excel('PAS7end_S7.xlsx')
tss = pd.read_excel('04TSS_DaiMon_S2.xlsx')
cbf = pd.read_excel('05CBF_DaiMon_S1.xlsx')
ppi = pd.read_excel('06PPI_DaiMon_S1.xlsx')

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 6))
subplot=['Bacillus', 'Nitrifikasi']
palette = sns.color_palette('tab20', n_colors=len(dla['Kolam'].unique()))
pond_colors = dict(zip(dla['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    ax = axs[i]
    for pond, pond_data in dla.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik DLA.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Bacillus', 'Lactobacillus', 'Nitrifikasi', 'Rhodobacter']
palette = sns.color_palette('tab20', n_colors=len(tnm['Kolam'].unique()))
pond_colors = dict(zip(tnm['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in tnm.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,92)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik TNM.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Bacillus', 'Lactobacillus', 'Nitrifikasi', 'Rhodobacter']
palette = sns.color_palette('tab20', n_colors=len(pas['Kolam'].unique()))
pond_colors = dict(zip(pas['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in pas.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,90)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik pas.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Bacillus', 'Lactobacillus', 'Nitrifikasi', 'Rhodobacter']
palette = sns.color_palette('tab20', n_colors=len(tss['Kolam'].unique()))
pond_colors = dict(zip(tss['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in tss.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,92)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik tss.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Bacillus', 'Lactobacillus', 'Nitrifikasi', 'Rhodobacter']
palette = sns.color_palette('tab20', n_colors=len(cbf['Kolam'].unique()))
pond_colors = dict(zip(cbf['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in cbf.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,95)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik cbf.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Bacillus', 'Lactobacillus']
palette = sns.color_palette('tab20', n_colors=len(ppi['Kolam'].unique()))
pond_colors = dict(zip(ppi['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in ppi.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,115)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Probiotik ppi.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase', 'Ragi', 'NaHCO₃']
palette = sns.color_palette('tab20', n_colors=len(pas['Kolam'].unique()))
pond_colors = dict(zip(pas['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in pas.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,92)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi pas.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase','BKK','Ragi', 'Dedak']
palette = sns.color_palette('tab20', n_colors=len(dla['Kolam'].unique()))
pond_colors = dict(zip(dla['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in dla.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,92)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi dla.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase','BKK','Ragi', 'NaHCO₃']
palette = sns.color_palette('tab20', n_colors=len(tnm['Kolam'].unique()))
pond_colors = dict(zip(tnm['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in tnm.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,92)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi tnm.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase','Dedak','Ragi']
palette = sns.color_palette('tab20', n_colors=len(tss['Kolam'].unique()))
pond_colors = dict(zip(tss['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in tss.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,85)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi tss.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase','Dedak','Ragi']
palette = sns.color_palette('tab20', n_colors=len(cbf['Kolam'].unique()))
pond_colors = dict(zip(cbf['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in cbf.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,85)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi cbf.jpg',bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
subplot=['Molase']
palette = sns.color_palette('tab20', n_colors=len(ppi['Kolam'].unique()))
pond_colors = dict(zip(ppi['Kolam'].unique(), palette))
for i, subplot in enumerate(subplot):
    row = i // 2  # Calculate the row index
    col = i % 2   # Calculate the column index
    ax = axs[row, col]
    for pond, pond_data in ppi.groupby('Kolam'):
        ax.plot(pond_data['DOP/DOC'], pond_data[subplot],'-o', color=pond_colors[pond], label=pond)
    ax.set_xlabel('DOP/DOC')
    ax.set_ylabel('Value')
    ax.set_title(subplot)
    ax.set_xlim(0,85)
plt.tight_layout()
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', title='Pond', bbox_to_anchor=(1, 0.96), ncol=1)
plt.savefig('Fermentasi ppi.jpg',)
plt.show()

# %%
dla.groupby('Kolam')[['Bacillus', 'Nitrifikasi']].sum()
# Out:
#        Bacillus  Nitrifikasi
# Kolam
# A1       38.500       17.950
# A2       55.650       20.100
# A3       59.500       18.400
# A4        8.550        4.200
# AX3       7.050        2.850
# B1       45.720       30.550
# B2       48.970       28.850
# B3       34.050       22.600
# B4        7.170        5.050
# D1       97.400       48.350
# D2       89.310       40.300
# D3       41.590       18.900
# D4       86.910       38.300
# D5       78.040       41.300
# D6       99.960       53.200
# E1       44.213       38.293
# E2       40.663       38.793
# E3       21.091       14.100
# E4       30.219       19.809
# TPC      11.295        8.900

# %%
ppi[['Salinitas (Salinity)','DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH',
       'Temp (M)', 'Temp (A)', 'Temp (N)', 'NH3', 'TAN ', 'NO₂',
       'NO₃', 'PO₄','T. Alk', 'Ca', 'Mg', 'Mg:Ca', 'T. Hard', 'TOM', 'GA',
       'Diatomae', 'BGA', 'Dino', 'Eugleno', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %']].astype(float)
# Out:
#      Salinitas (Salinity)  DO (M)  DO (A)  DO (N)  pH (M)  pH (A)  Range pH  \
# 0                    21.0     NaN     NaN     NaN    8.76    8.76      0.00
# 1                    22.0     NaN     NaN     NaN    8.78    8.79      0.01
# 2                    20.0    6.55     NaN     NaN    8.86    8.87      0.01
# 3                    24.0    6.74     NaN     NaN    8.60    8.59     -0.01
# 4                    25.0    6.63     NaN     NaN    8.43    8.45      0.02
# ..                    ...     ...     ...     ...     ...     ...       ...
# 898                   NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 899                   NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 900                   NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 901                   NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 902                   NaN     NaN     NaN     NaN     NaN     NaN       NaN
#
# ...

# %%
def boxplot_all(df):
    nama_kolom=['Salinitas (Salinity)','DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH',
       'Temp (M)', 'Temp (A)', 'Temp (N)']
    plt.figure(figsize=(18,12))
    for i in range(len(nama_kolom)):
        plt.subplot(4,3,i+1)
        sns.boxplot(data=tss, x='Kolam', y=nama_kolom[i],palette='tab20')
#         plt.title(f'Rain vs {nama_kolom[i]}')
    plt.suptitle(f'Boxplot Physical Parameter.png')
    plt.tight_layout()
    plt.savefig(f'boxplot phy tss')

# %%
boxplot_all(tss)

# %%
def boxplot_all(df):
    nama_kolom=['NH3','TAN ', 'NO₂','NO₃', 'PO₄','T. Alk', 'Mg:Ca', 'T. Hard', 'TOM', ]
    plt.figure(figsize=(18,12))
    for i in range(len(nama_kolom)):
        plt.subplot(3,3,i+1)
        sns.boxplot(data=tss, x='Kolam', y=nama_kolom[i],palette='tab20')
#         plt.title(f'Rain vs {nama_kolom[i]}')
    plt.suptitle(f'Boxplot Parameter Kimia.png')
    plt.tight_layout()
    plt.savefig(f'boxplot kimia tss')

# %%
boxplot_all(tss)

# %%
def boxplot_all(df):
    nama_kolom=['GA', 'Diatomae', 'BGA', 'Dino', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %']
    plt.figure(figsize=(18,12))
    for i in range(len(nama_kolom)):
        plt.subplot(3,3,i+1)
        sns.boxplot(data=tss, x='Kolam', y=nama_kolom[i],palette='tab20')
#         plt.title(f'Rain vs {nama_kolom[i]}')
    plt.suptitle(f'Boxplot Parameter Biologi.png')
    plt.tight_layout()
    plt.savefig(f'boxplot bio tss')

# %%
boxplot_all(tss)

# %%
dla.groupby('Kolam')[['Molase','BKK','Ragi','Dedak']].sum()
# Out:
#        Molase  BKK   Ragi  Dedak
# Kolam
# A1      58.00  0.0  0.000    0.0
# A2      83.50  0.0  0.550   10.0
# A3      82.50  0.0  0.050    5.0
# A4      19.10  0.0  0.150   15.0
# AX3     13.70  0.0  0.000    0.0
# B1     105.00  0.0  8.085   35.0
# B2     119.60  0.0  0.650   20.0
# B3      87.00  0.0  0.260   12.5
# B4      22.60  0.0  0.000    0.0
# D1     196.10  3.0  0.100   10.0
# D2     172.00  1.5  0.000    0.0
# D3      98.80  1.0  0.200   20.0
# D4     167.30  1.5  0.000    0.0
# D5     165.50  1.5  0.000    0.0
# D6     192.10  2.0  0.000    0.0
# E1      55.30  0.0  0.550   10.0
# E2      54.30  0.0  0.550   10.0
# E3      25.05  0.0  0.975   12.0
# E4      35.40  0.0  0.395    7.1
# TPC     29.94  0.8  0.000    0.0

# %%
tnm.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#        Molase   BKK    Ragi  NaHCO₃  Dedak
# Kolam
# A1      377.5   8.0  1210.0  2600.0    0.0
# A2      376.0   7.0  1170.0  2600.0    0.0
# A3      330.0   8.0  1175.0     2.8    0.0
# A4      218.5  10.5   750.0     2.8    0.0
# A5      319.5  10.5  1170.0     2.8    0.0
# A6      334.5  14.0  1170.0     3.0    0.0

# %%
tss.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#        Molase  BKK   Ragi  NaHCO₃  Dedak
# Kolam
# B1      42.75  0.0   36.0     0.0  20.75
# B2      24.00  0.0   23.5     0.0  18.25
# B3      32.75  0.0   73.5     0.0  28.25
# B4      48.75  0.0   73.5     0.0  28.25
# C1      48.75  0.0   74.5     0.0  33.75
# C2      47.25  0.0   73.5     0.0  28.25
# C3      58.75  0.0   74.5     0.0  33.75
# C4      48.75  0.0  574.5     0.0  33.75

# %%
pas.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#        Molase  BKK   Ragi  NaHCO₃  Dedak
# Kolam
# A10     84.75  0.0  461.0    42.5    0.0
# A3      99.75  0.0  757.0    35.0    0.0
# A9      64.75  0.0  361.0     7.5    0.0
# B10    109.75  0.0  811.0    50.0    0.0
# B3     117.75  0.0  861.0    45.0    0.0
# B4     103.75  0.0  761.0    55.0    0.0
# B5     104.75  0.0  811.0    30.0    0.0
# B6      66.75  0.0  361.0    15.0    0.0
# B7      96.75  0.0  761.0    35.0    0.0
# B8      99.75  0.0  661.0    35.0    0.0
# B9     104.75  0.0  861.0    40.0    0.0
# C1     109.75  0.0  811.0    50.0    0.0
# C10    154.75  0.0  866.0    55.0    0.0
# C2     119.75  0.0  416.0    30.0    0.0
# C3     144.75  0.0  711.0    25.0    0.0
# C4     129.75  0.0  666.0    30.0    0.0
# C5      74.75  0.0  511.0    15.0    0.0
# C6     144.75  0.0  661.0    40.0    0.0
# C7     109.75  0.0  861.0    45.0    0.0
# C8     104.75  0.0  811.0    45.0    0.0

# %%
cbf.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#          Molase  BKK   Ragi  NaHCO₃  Dedak
# Kolam
# B1     118.6810  0.0  150.0     0.0   10.0
# B2      95.5265  0.0  150.0     0.0   10.0
# B3     131.4165  0.0  150.0     0.0   10.0
# B4     121.4110  0.0  150.0     0.0   10.0

# %%
ppi.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#        Molase  BKK  Ragi  NaHCO₃  Dedak
# Kolam
# C1      130.7  0.0   0.0     0.0    0.0
# C2       86.2  0.0   0.0     0.0    0.0
# C3       83.2  0.0   0.0     0.0    0.0
# C4       57.7  0.0   0.0     0.0    0.0
# C5       57.7  0.0   0.0     0.0    0.0
# C6       63.7  0.0   0.0     0.0    0.0
# C7       98.7  0.0   0.0     0.0    0.0

# %%
tss.groupby('Kolam')[['Molase','BKK','Ragi', 'NaHCO₃','Dedak']].sum()
# Out:
#        Molase  BKK   Ragi  NaHCO₃  Dedak
# Kolam
# B1      42.75  0.0   36.0     0.0  20.75
# B2      24.00  0.0   23.5     0.0  18.25
# B3      32.75  0.0   73.5     0.0  28.25
# B4      48.75  0.0   73.5     0.0  28.25
# C1      48.75  0.0   74.5     0.0  33.75
# C2      47.25  0.0   73.5     0.0  28.25
# C3      58.75  0.0   74.5     0.0  33.75
# C4      48.75  0.0  574.5     0.0  33.75

# %%
ppi.groupby('Kolam')[['Bacillus', 'Lactobacillus', 'Nitrifikasi', 'Rhodobacter']].sum()
# Out:
#        Bacillus  Lactobacillus  Nitrifikasi  Rhodobacter
# Kolam
# C1      16325.0         7845.0          0.0          0.0
# C2      13036.0         6187.5          0.0          0.0
# C3      12750.0         5917.5          0.0          0.0
# C4      10319.0         4735.0          0.0          0.0
# C5      10319.0         4710.0          0.0          0.0
# C6      10891.0         4720.0          0.0          0.0
# C7      14037.0         6882.5          0.0          0.0

# %%
dla.loc[dla['Kolam'].isin(['D2','D4','D5','D6','TPC']),'Fermentasi']='BKK'
dla.loc[dla['Kolam'].isin(['A2','A3','A4','B1','B2','B3','D1','D3','E1','E2','E3','E4']),'Fermentasi']='Ragi+Dedak'
dla.loc[dla['Kolam'].isin(['D1','D3']),'Fermentasi']='BKK+Ragi+Dedak'

# %%
dla.loc[dla['Kolam'].isin(['A1','AX3','B4']),'Fermentasi']='Molase'

# %%
dla=dla.sort_values(by='Fermentasi')

# %%
columns_to_plot = list(['NH3','TAN ', 'NO₂','NO₃', 'PO₄','T. Alk', 'Mg:Ca', 'T. Hard', 'TOM', ])
num_plots = len(columns_to_plot)
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 12))
sns.set(style="whitegrid")

for i, column in enumerate(columns_to_plot):
    row = i // num_cols
    col = i % num_cols
    sns.barplot(x="Fermentasi", y=column, data=dla.dropna(subset='Fermentasi'), palette=['darkgreen','darkorange','darkred','darkblue'], ax=axes[row, col], ci=None)
    axes[row, col].set_title(column)
    
    # Add label values
    for p in axes[row, col].patches:
        axes[row, col].text(p.get_x() + p.get_width() / 2, p.get_height(), '{:.1f}'.format(p.get_height()), ha='center', va='bottom')

plt.tight_layout()
plt.savefig('subplot_kimia_dla.jpg')
plt.show()

# %%
columns_to_plot = ['Salinitas (Salinity)', 'DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH', 'Temp (M)', 'Temp (A)', 'Temp (N)']
num_plots = len(columns_to_plot)
num_rows = 3
num_cols = 4
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 12))
sns.set(style="whitegrid")

for i, column in enumerate(columns_to_plot):
    row = i // num_cols
    col = i % num_cols
    sns.barplot(x="Fermentasi", y=column, data=dla.dropna(subset='Fermentasi'), palette=['darkgreen','darkorange','darkred','darkblue'], ax=axes[row, col], ci=None)
    axes[row, col].set_title(column)
    
    # Add label values
    for p in axes[row, col].patches:
        axes[row, col].text(p.get_x() + p.get_width() / 2, p.get_height(), '{:.1f}'.format(p.get_height()), ha='center', va='bottom')

plt.tight_layout()
plt.savefig('subplot_fisika_dla.jpg')
plt.show()

# %%
columns_to_plot = list(['GA', 'Diatomae', 'BGA', 'Dino', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %'])
num_plots = len(columns_to_plot)
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 12))
sns.set(style="whitegrid")

for i, column in enumerate(columns_to_plot):
    row = i // num_cols
    col = i % num_cols
    sns.barplot(x="Fermentasi", y=column, data=dla.dropna(subset='Fermentasi'), palette=['darkgreen','darkorange','darkred','darkblue'], ax=axes[row, col], ci=None)
    axes[row, col].set_title(column)
    
    # Add label values
    for p in axes[row, col].patches:
        axes[row, col].text(p.get_x() + p.get_width() / 2, p.get_height(), '{:.1f}'.format(p.get_height()), ha='center', va='bottom')

plt.tight_layout()
plt.savefig('subplot_bio_dla.jpg')
plt.show()

# %%
import scipy.stats as stats

# %%
bkk=dla.loc[dla['Fermentasi']=='BKK']
bkkragi=dla.loc[dla['Fermentasi']=='BKK+Ragi+Dedak']
ragidedak=dla.loc[dla['Fermentasi']=='Ragi+Dedak']

# %%
fis_dla=stats.kruskal(bkk[['Salinitas (Salinity)','DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH',
       'Temp (M)', 'Temp (A)', 'Temp (N)']],bkkragi[['Salinitas (Salinity)','DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH',
       'Temp (M)', 'Temp (A)', 'Temp (N)']],ragidedak[['Salinitas (Salinity)','DO (M)', 'DO (A)', 'DO (N)', 'pH (M)', 'pH (A)', 'Range pH',
       'Temp (M)', 'Temp (A)', 'Temp (N)']])

# %%
fis_dla=pd.DataFrame(fis_dla)

# %%
fis_dla=fis_dla.rename(columns={0:'Salinitas (Salinity)',1:'DO (M)',2: 'DO (A)', 3:'DO (N)',4: 'pH (M)', 5:'pH (A)',6: 'Range pH',
       7:'Temp (M)',8: 'Temp (A)', 9:'Temp (N)'})

# %%
fis_dla['']='statistic','pvalue'

# %%
fis_dla.set_index('').iloc[:,7:]
# Out:
#                Temp (M)  Temp (A)  Temp (N)
#
# statistic  3.311893e+01  6.887614  9.607298
# pvalue     6.431551e-08  0.031943  0.008200

# %%
kim_dla=stats.kruskal(bkk[['NO₃','T. Alk', 'Mg:Ca', 'T. Hard', 'TOM']],bkkragi[['NO₃','T. Alk', 'Mg:Ca', 'T. Hard', 'TOM']],ragidedak[['NO₃','T. Alk', 'Mg:Ca', 'T. Hard', 'TOM']])

# %%
kim_dla=pd.DataFrame(kim_dla)

# %%
kim_dla=kim_dla.rename(columns={0:'NO₃',1:'T. Alk',2: 'Mg:Ca',3: 'T. Hard',4: 'TOM'})

# %%
kim_dla['']='statistic','pvalue'

# %%
kim_dla.set_index('')
# Out:
#                 NO₃     T. Alk     Mg:Ca   T. Hard       TOM
#
# statistic  0.134574  24.615160  2.795154  0.539679  9.338515
# pvalue     0.934927   0.000005  0.247195  0.763502  0.009379

# %%
bkk1=bkk[['NH3','TAN ','NO₂','NO₃', 'PO₄']].dropna()
bkk2=bkkragi[['NH3','TAN ','NO₂','NO₃', 'PO₄']].dropna()
bkk3=ragidedak[['NH3','TAN ','NO₂','NO₃', 'PO₄']].dropna()

# %%
kim_dla1=stats.kruskal(bkk1,bkk2,bkk3)

# %%
kim_dla1=pd.DataFrame(kim_dla1)
kim_dla1['']='statistic','pvalue'

# %%
kim_dla1=kim_dla1.rename(columns={0:'NH3',1:'TAN ',2:'NO₂',3:'NO₃',4: 'PO₄'})

# %%
kim_dla1.set_index('')
# Out:
#                  NH3       TAN        NO₂       NO₃       PO₄
#
# statistic  21.266382  22.968995  2.859058  0.082935  2.001971
# pvalue      0.000024   0.000010  0.239422  0.959381  0.367517

# %%
bio_dla=stats.kruskal(bkk[['GA', 'Diatomae', 'BGA', 'Dino', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %']],bkkragi[['GA', 'Diatomae', 'BGA', 'Dino', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %']],ragidedak[['GA', 'Diatomae', 'BGA', 'Dino', 'Zoo', 'Total Plankton', 'TVC', 'TBC', 'TVC:TBC %']])

# %%
bio_dla=pd.DataFrame(bio_dla)

# %%
bio_dla=bio_dla.rename(columns={0:'GA',1: 'Diatomae',2: 'BGA',3: 'Dino',4: 'Zoo',5: 'Total Plankton',6: 'TVC',7: 'TBC',8: 'TVC:TBC %'})

# %%
bio_dla['']='statistic','pvalue'

# %%
bio_dla.set_index('').iloc[:,:4]
# Out:
#                  GA  Diatomae       BGA          Dino
#
# statistic  9.232835  2.253888  0.297724  6.163113e+01
# pvalue     0.009888  0.324022  0.861688  4.139717e-14

# %%
s_dla = pd.read_excel('01DLA_Sampling_S19.xlsx')

# %%
dla_panen = pd.read_excel('01DLA_Final Harvest_S19.xlsx')

# %%
s_dla.loc[s_dla['Kolam'].isin(['D2','D4','D5','D6','TPC']),'Fermentasi']='BKK'
s_dla.loc[s_dla['Kolam'].isin(['A2','A3','A4','B1','B2','B3','D1','D3','E1','E2','E3','E4']),'Fermentasi']='Ragi+Dedak'
s_dla.loc[s_dla['Kolam'].isin(['D1','D3']),'Fermentasi']='BKK+Ragi+Dedak'

# %%
s_dla.loc[s_dla['Kolam'].isin(['A1','AX3','B4']),'Fermentasi']='Molase'

# %%
s_dla=s_dla.sort_values(by=['Fermentasi','Kolam'])

# %%
s_dla[['Fermentasi','Kolam']].drop_duplicates()
# Out:
#         Fermentasi Kolam
# 9              BKK    D2
# 11             BKK    D4
# 12             BKK    D5
# 13             BKK    D6
# 18             BKK   TPC
# 8   BKK+Ragi+Dedak    D1
# 10  BKK+Ragi+Dedak    D3
# 0           Molase    A1
# 19          Molase   AX3
# 7           Molase    B4
# 1       Ragi+Dedak    A2
# 2       Ragi+Dedak    A3
# 3       Ragi+Dedak    A4
# 4       Ragi+Dedak    B1
# 5       Ragi+Dedak    B2
# 6       Ragi+Dedak    B3
# 14      Ragi+Dedak    E1
# 15      Ragi+Dedak    E2
# 16      Ragi+Dedak    E3
# 17      Ragi+Dedak    E4

# %%
subplots = ['ADG']
palette = ['darkgreen','darkgreen','darkgreen','darkgreen','darkgreen','darkorange','darkorange','darkred','darkred','darkred','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue']
pond_colors = dict(zip(s_dla['Kolam'].unique(), palette))

fig, axes = plt.subplots(4, 5, figsize=(16, 12))

for i, pond in enumerate(s_dla['Kolam'].unique()):
    ax = axes[i // 5, i % 5]
    for subplot in subplots:
        pond_data = s_dla[s_dla['Kolam'] == pond]
        ax.plot(pond_data['DOC'], pond_data[subplot], '-o', color=pond_colors[pond], label=subplot)
    ax.set_xlabel('DOC')
    ax.set_ylabel('Value')
    ax.set_ylim(0,1)
    ax.set_title(pond)
    
# Remove empty subplots
if len(s_dla['Kolam'].unique()) < 12:
    empty_subplots = 12 - len(s_dla['Kolam'].unique())
    for i in range(empty_subplots):
        row = (len(s_dla['Kolam'].unique()) + i) // 3
        col = (len(s_dla['Kolam'].unique()) + i) % 3
        fig.delaxes(axes[row, col])

plt.tight_layout()
plt.savefig('ADG.jpg')
plt.show()

# %%
dla_panen['ADG Final']=dla_panen['MBW']/dla_panen['DOC']

# %%
dla_panen.loc[dla_panen['Kolam'].isin(['D2','D4','D5','D6','TPC']),'Fermentasi']='BKK'
dla_panen.loc[dla_panen['Kolam'].isin(['A2','A3','A4','B1','B2','B3','D1','D3','E1','E2','E3','E4']),'Fermentasi']='Ragi+Dedak'
dla_panen.loc[dla_panen['Kolam'].isin(['D1','D3']),'Fermentasi']='BKK+Ragi+Dedak'

# %%
dla_panen.loc[dla_panen['Kolam'].isin(['A1','AX3','B4']),'Fermentasi']='Molase'

# %%
dla_panen=dla_panen.sort_values(by=['Fermentasi','Kolam'])

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(8, 6))
custom_palette = ["darkgreen", "darkorange",'darkred',"darkblue"]
sns.barplot(x='Kolam', y="ADG Final", data=dla_panen, palette=palette,ax=ax)

# Adjust the aspect ratio
ax.set_aspect('auto')  # 'auto' ensures equal aspect ratio

# Create a custom legend
legend_labels = ['BKK', 'BKK+Ragi+Dedak','Molase','Ragi+Dedak']  # Replace with your desidarkorange labels for the two status values
handles = [plt.Line2D([], [], color=color, marker='s', linestyle='') for color in custom_palette]
ax.legend(handles, legend_labels,loc='lower left')
plt.title('ADG Final')
plt.tight_layout()
plt.savefig('ADG Final.jpg')
plt.show()  # Display the plot

# %%
i
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(8, 6))
custom_palette = ["darkgreen", "darkorange", "darkred", "darkblue"]
sns.barplot(x='Fermentasi', y="ADG Final", data=dla_panen, palette=custom_palette, ax=ax,ci=None)

# Adjust the aspect ratio
ax.set_aspect('auto')  # 'auto' ensures equal aspect ratio

# Add label values
for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Create a custom legend
legend_labels = ['BKK', 'BKK+Ragi+Dedak', 'Molase', 'Ragi+Dedak']
handles = [plt.Line2D([], [], color=color, marker='s', linestyle='') for color in custom_palette]
ax.legend(handles, legend_labels, loc='lower left')
plt.title('ADG')
plt.tight_layout()
plt.savefig('ADG Final1.jpg')
plt.show()  # Display the plot

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(8, 6))
custom_palette = ["darkgreen", "darkorange",'darkred',"darkblue"]
sns.barplot(x='Kolam', y="MBW", data=dla_panen, palette=palette,ax=ax)

# Adjust the aspect ratio
ax.set_aspect('auto')  # 'auto' ensures equal aspect ratio

# Create a custom legend
legend_labels = ['BKK', 'BKK+Ragi+Dedak','Molase','Ragi+Dedak']  # Replace with your desidarkorange labels for the two status values
handles = [plt.Line2D([], [], color=color, marker='s', linestyle='') for color in custom_palette]
ax.legend(handles, legend_labels,loc='lower left')
plt.title('MBW')
plt.tight_layout()
plt.savefig('MBW.jpg')
plt.show()  # Display the plot

# %%
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize=(8, 6))
custom_palette = ["darkgreen", "darkorange", "darkred", "darkblue"]
sns.barplot(x='Fermentasi', y="MBW", data=dla_panen, palette=custom_palette, ax=ax,ci=None)

# Adjust the aspect ratio
ax.set_aspect('auto')  # 'auto' ensures equal aspect ratio

# Add label values
for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Create a custom legend
legend_labels = ['BKK', 'BKK+Ragi+Dedak', 'Molase', 'Ragi+Dedak']
handles = [plt.Line2D([], [], color=color, marker='s', linestyle='') for color in custom_palette]
ax.legend(handles, legend_labels, loc='lower left')
plt.title('MBW')
plt.tight_layout()
plt.savefig('MBW Final1.jpg')
plt.show()  # Display the plot

# %%
panen_bkk=dla_panen.loc[dla_panen['Fermentasi']=='BKK']
panen_bkk1=dla_panen.loc[dla_panen['Fermentasi']=='BKK+Ragi+Dedak']
panen_bkk2=dla_panen.loc[dla_panen['Fermentasi']=='Molase']
panen_bkk3=dla_panen.loc[dla_panen['Fermentasi']=='Ragi+Dedak']

# %%
panen_stat=stats.kruskal(panen_bkk[['ADG Final','MBW','FCR','SR ']],panen_bkk1[['ADG Final','MBW','FCR','SR ']],panen_bkk2[['ADG Final','MBW','FCR','SR ']],panen_bkk3[['ADG Final','MBW','FCR','SR ']])

# %%
panen_stat=pd.DataFrame(panen_stat)

# %%
panen_stat['']='statistic','pvalue'

# %%
panen_stat.rename(columns={0:'ADG Final',1:'MBW',2:'FCR',3:'SR '}).set_index('')
# Out:
#            ADG Final       MBW        FCR        SR
#
# statistic   0.617143  0.838571  11.981429  12.725714
# pvalue      0.892497  0.840221   0.007447   0.005269
